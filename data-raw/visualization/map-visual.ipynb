# %%
import geopandas as gpd
import folium
from IPython.display import display
import pandas as pd

# %%
shapefile_paths = [
    "../MSS_nodes/dsm2_nodes_newcs_extranodes.shp",
    "../fc2024.01_chan/FC2024.01_channels_centerlines.shp"
]

# %%
nodes = gpd.read_file(shapefile_paths[0])
nodes.head
# Out:
# <bound method NDFrame.head of                X          Y   id                        geometry
# 0    586524.5000  4214278.5  329      POINT (586524.5 4214278.5)
# 1    595501.8125  4215164.0  328      POINT (595501.812 4215164)
# 2    587823.0625  4224132.5  327    POINT (587823.062 4224132.5)
# 3    611764.3125  4234500.0  326      POINT (611764.312 4234500)
# 4    609429.0625  4235459.0  325      POINT (609429.062 4235459)
# ..           ...        ...  ...                             ...
# 473          NaN        NaN  811   POINT (640955.51 4185200.504)
# 474          NaN        NaN  812  POINT (640236.914 4185018.152)
# 475          NaN        NaN  814  POINT (638627.967 4184416.817)
# 476          NaN        NaN  813  POINT (639130.486 4183087.804)
# 477          NaN        NaN  815  POINT (631626.258 4183226.381)
#
# [478 rows x 4 columns]>

# %%
channels = gpd.read_file(shapefile_paths[1])
channels.head
# Out:
# <bound method NDFrame.head of       id                                           geometry
# 0      1  LINESTRING (652291.736 4172448.043, 652209.821...
# 1      2  LINESTRING (652401.235 4174797.442, 652581.296...
# 2      3  LINESTRING (651808.247 4176015.422, 651766.413...
# 3      4  LINESTRING (650024.633 4176799.368, 649933.498...
# 4      5  LINESTRING (648990.218 4180561.514, 648949.832...
# ..   ...                                                ...
# 546  819  LINESTRING (640236.667 4185024.396, 639714.773...
# 547  820  LINESTRING (639153.103 4183088.611, 639153.56 ...
# 548  821  LINESTRING (638934.638 4184888.455, 638822.624...
# 549  822  LINESTRING (638615.055 4184423.33, 638562.21 4...
# 550  823  LINESTRING (631626.258 4183226.381, 631559.926...
#
# [551 rows x 2 columns]>

# %%
# nodes to highlight, based on figure 

nodes_to_highlight = [112, 176, 69]
nodes_filter = nodes[nodes['id'].isin(nodes_to_highlight)]
nodes_filter.head
# Out:
# <bound method NDFrame.head of                X           Y   id                       geometry
# 134  632155.4375  4186851.25  176  POINT (632155.438 4186851.25)
# 207  634764.4375  4193850.50  112   POINT (634764.438 4193850.5)
# 287  628267.0000  4185764.00   69         POINT (628267 4185764)>

# %%
# read in channel dataframe 

channels_with_numbers = pd.read_csv('../channel_names_from_h5.csv')
channels_with_numbers = channels_with_numbers.rename(columns={'chan_no': 'id'})
channels_with_numbers.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0    name   id distance variable interval period_op  \
# 0             0     ANH   52        0     flow    15MIN      inst
# 1             1     ANH   52        0    stage    15MIN      inst
# 2             2     BDT   11       81     flow    15MIN      inst
# 3             3     BDT   11       81    stage    15MIN      inst
# 4             4  CCF_up  232      500    stage    15MIN      inst
# ..          ...     ...  ...      ...      ...      ...       ...
# 156         156     VNS   17     4706    stage    15MIN      inst
# 157         157     VON  410        0     flow    15MIN      inst
# 158         158     VON  410        0    stage    15MIN      inst
# 159         159     WCI  232      457     flow    15MIN      inst
# 160         160     WCI  232      457    stage    15MIN      inst
#
#                           file
# 0    ./output/FPV2Mb_hydro.dss
# 1    ./output/FPV2Mb_hydro.dss
# 2    ./output/FPV2Mb_hydro.dss
# 3    ./output/FPV2Mb_hydro.dss
# 4      ./output/FPV2Mb_CCF.dss
# ..                         ...
# 156  ./output/FPV2Mb_hydro.dss
# 157  ./output/FPV2Mb_hydro.dss
# 158  ./output/FPV2Mb_hydro.dss
# 159  ./output/FPV2Mb_hydro.dss
# 160  ./output/FPV2Mb_hydro.dss
#
# [161 rows x 8 columns]>

# %%
channels_merge = pd.merge(
    channels,
    channels_with_numbers,
    how='left',
    left_on='id',
    right_on='id'
)
channels_merge.head
# Out:
# <bound method NDFrame.head of       id                                           geometry  Unnamed: 0 name  \
# 0      1  LINESTRING (652291.736 4172448.043, 652209.821...         NaN  NaN
# 1      2  LINESTRING (652401.235 4174797.442, 652581.296...         NaN  NaN
# 2      3  LINESTRING (651808.247 4176015.422, 651766.413...         NaN  NaN
# 3      4  LINESTRING (650024.633 4176799.368, 649933.498...        28.0  DVI
# 4      4  LINESTRING (650024.633 4176799.368, 649933.498...        29.0  DVI
# ..   ...                                                ...         ...  ...
# 645  820  LINESTRING (639153.103 4183088.611, 639153.56 ...       136.0  SUR
# 646  820  LINESTRING (639153.103 4183088.611, 639153.56 ...       137.0  SUR
# 647  821  LINESTRING (638934.638 4184888.455, 638822.624...         NaN  NaN
# 648  822  LINESTRING (638615.055 4184423.33, 638562.21 4...         NaN  NaN
# 649  823  LINESTRING (631626.258 4183226.381, 631559.926...         NaN  NaN
#
#     distance variable interval period_op                       file
# 0        NaN      NaN      NaN       NaN                        NaN
# 1        NaN      NaN      NaN       NaN                        NaN
# 2        NaN      NaN      NaN       NaN                        NaN
# 3      12870     flow    15MIN      inst  ./output/FPV2Mb_hydro.dss
# 4      12870    stage    15MIN      inst  ./output/FPV2Mb_hydro.dss
# ..       ...      ...      ...       ...                        ...
# 645     1321     flow    15MIN      inst  ./output/FPV2Mb_hydro.dss
# 646     1321    stage    15MIN      inst  ./output/FPV2Mb_hydro.dss
# 647      NaN      NaN      NaN       NaN                        NaN
# 648      NaN      NaN      NaN       NaN                        NaN
# 649      NaN      NaN      NaN       NaN                        NaN
#
# [650 rows x 9 columns]>

# %%
# Ensure the CRS is EPSG:4326 (latitude/longitude)
channels_merge = channels_merge.to_crs(epsg=4326)

# Filter for specific IDs
filtered_channels = channels_merge[channels_merge['id'].isin([211, 79, 134])]

# Initialize the map centered on the average location of the filtered geometries
centroid = filtered_channels.geometry.unary_union.centroid
m = folium.Map(location=[centroid.y, centroid.x], zoom_start=12)

# Add polylines for the filtered LineStrings
for _, row in filtered_channels.iterrows():
    popup_content = f"""
    id = {row['id']}<br>
    name = {row.get('name', 'N/A')}<br>
    distance = {row.get('distance', 'N/A')}<br>
    variable = {row.get('variable', 'N/A')}<br>
    interval = {row.get('interval', 'N/A')}<br>
    period_op = {row.get('period_op', 'N/A')}
    """
    
    # Extract coordinates for the LineString
    coordinates = [(point[1], point[0]) for point in row.geometry.coords]  # Convert (x, y) to (lat, lon)
    
    # Add the LineString to the map
    folium.PolyLine(
        locations=coordinates,
        color='darkgreen',
        popup=folium.Popup(popup_content, max_width=300)
    ).add_to(m)

# Display the map
m
# Out:
# /var/folders/45/p22_x33n4s1dbmnzjdjzfr_80000gn/T/ipykernel_3392/4019552048.py:8: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   centroid = filtered_channels.geometry.unary_union.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_604e2f4278796fdfc62e93056ee26622 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_604e2f4278796fdfc62e93056ee26622&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_604e2f4278796fdfc62e93056ee26622 = L.map(
#                 &quot;map_604e2f4278796fdfc62e93056ee26622&quot;,
#                 {
#                     center: [37.84916301024997, -121.49975569080779],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b648cb9bd165298d8cda7c31e05181e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b648cb9bd165298d8cda7c31e05181e.addTo(map_604e2f4278796fdfc62e93056ee26622);
#
#
#             var poly_line_33c793e174a9f15b72a18610eb4017c8 = L.polyline(
#                 [[37.80458853783997, -121.53305884547657], [37.80590478689147, -121.53552215539725], [37.807027452807624, -121.538549396369], [37.81026714827158, -121.54284129038292]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_604e2f4278796fdfc62e93056ee26622);
#
#
#         var popup_6abeee94900a2365d0f4d30b1ec1b80a = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_e6fe4982244e5bb32ed274f2e0b3db8b = $(`&lt;div id=&quot;html_e6fe4982244e5bb32ed274f2e0b3db8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     id = 79&lt;br&gt;     name = OAD&lt;br&gt;     distance = 3457&lt;br&gt;     variable = flow&lt;br&gt;     interval = 15MIN&lt;br&gt;     period_op = inst     &lt;/div&gt;`)[0];
#                 popup_6abeee94900a2365d0f4d30b1ec1b80a.setContent(html_e6fe4982244e5bb32ed274f2e0b3db8b);
#
#
#
#         poly_line_33c793e174a9f15b72a18610eb4017c8.bindPopup(popup_6abeee94900a2365d0f4d30b1ec1b80a)
#         ;
#
#
#
#
#             var poly_line_e514bdb8953d5d87284aeb0c81d61985 = L.polyline(
#                 [[37.80458853783997, -121.53305884547657], [37.80590478689147, -121.53552215539725], [37.807027452807624, -121.538549396369], [37.81026714827158, -121.54284129038292]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_604e2f4278796fdfc62e93056ee26622);
#
#
#         var popup_51f161f5132c8ced643935535f26f6d7 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_7c84be31d97dcf6eafea67fc41ccf4c7 = $(`&lt;div id=&quot;html_7c84be31d97dcf6eafea67fc41ccf4c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     id = 79&lt;br&gt;     name = OAD&lt;br&gt;     distance = 3457&lt;br&gt;     variable = stage&lt;br&gt;     interval = 15MIN&lt;br&gt;     period_op = inst     &lt;/div&gt;`)[0];
#                 popup_51f161f5132c8ced643935535f26f6d7.setContent(html_7c84be31d97dcf6eafea67fc41ccf4c7);
#
#
#
#         poly_line_e514bdb8953d5d87284aeb0c81d61985.bindPopup(popup_51f161f5132c8ced643935535f26f6d7)
#         ;
#
#
#
#
#             var poly_line_1d6d2ef7dc81d6adcd9f0a78d2560912 = L.polyline(
#                 [[37.80458853783997, -121.53305884547657], [37.80590478689147, -121.53552215539725], [37.807027452807624, -121.538549396369], [37.81026714827158, -121.54284129038292]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkgreen&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;darkgreen&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_604e2f4278796fdfc62e93056ee26622);
#
#
#         var popup_a9d77479f2e5964b27d08062f80b375d = L.popup({
#   &quot;maxWidth&

# %%
import geopandas as gpd
import folium
from IPython.display import display

def create_multi_layer_map(shapefile_paths, filtered_gdf=None):
    """
    Creates an interactive map with multiple shapefile layers and optional filtered points in red.
    
    Parameters:
    - shapefile_paths: List of file paths to the shapefiles.
    - filtered_gdf: A GeoDataFrame with filtered points to display in red (optional).
    """
    # Initialize a list to store valid GeoDataFrames and their centroids
    gdfs = []
    all_centroids = []
    
    for path in shapefile_paths:
        # Read shapefile
        gdf = gpd.read_file(path)
        
        # Ensure the CRS is EPSG:4326
        if gdf.crs != "EPSG:4326":
            gdf = gdf.to_crs("EPSG:4326")
        
        # Ensure filtered GeoDataFrame is in the correct CRS
        if filtered_gdf is not None and filtered_gdf.crs != "EPSG:4326":
            filtered_gdf = filtered_gdf.to_crs("EPSG:4326")
        
        # Check if there are valid geometries
        if gdf.is_empty.any():
            print(f"Warning: Some geometries in {path} are empty and will be ignored.")
            gdf = gdf[~gdf.is_empty]  # Remove empty geometries
        
        # Compute the centroid in EPSG:4326 (no need for reprojection)
        centroid = gdf.geometry.centroid
        center = [centroid.y.mean(), centroid.x.mean()]
        
        # Append to the list
        gdfs.append((gdf, center))
        all_centroids.append(center)
    
    # Calculate map center based on all layers
    avg_lat = sum([c[0] for c in all_centroids]) / len(all_centroids)
    avg_lon = sum([c[1] for c in all_centroids]) / len(all_centroids)
    
    # Create a Folium map centered on the average centroid
    m = folium.Map(location=[avg_lat, avg_lon], zoom_start=10)
    
    # Add each shapefile as a separate layer to the map
    for idx, (gdf, _) in enumerate(gdfs):
        folium.GeoJson(
            gdf,
            name=f"Layer {idx + 1}: {shapefile_paths[idx].split('/')[-1]}"
        ).add_to(m)
    
    # If filtered_gdf is provided, add the filtered points in red
    if filtered_gdf is not None:
        for _, row in filtered_gdf.iterrows():
            folium.Marker(
                location=[row['geometry'].y, row['geometry'].x], 
                popup=f"ID: {row['id']}", 
                icon=folium.Icon(color='red', icon="circle")
            ).add_to(m)
    
    # Add layer control
    folium.LayerControl().add_to(m)
    
    # Display the map in the notebook
    display(m)

# %%
create_multi_layer_map(shapefile_paths, nodes_filter)
# Out:
# /var/folders/45/p22_x33n4s1dbmnzjdjzfr_80000gn/T/ipykernel_3392/1209274723.py:35: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = gdf.geometry.centroid
# /var/folders/45/p22_x33n4s1dbmnzjdjzfr_80000gn/T/ipykernel_3392/1209274723.py:35: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = gdf.geometry.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_688bb2cd03ab3c2a2b9fbb17a8fac499 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_688bb2cd03ab3c2a2b9fbb17a8fac499&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_688bb2cd03ab3c2a2b9fbb17a8fac499 = L.map(
#                 &quot;map_688bb2cd03ab3c2a2b9fbb17a8fac499&quot;,
#                 {
#                     center: [38.04570257159147, -121.61176339083228],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d38425f93b4d5ccd48f0cb7a8abc4b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d38425f93b4d5ccd48f0cb7a8abc4b5.addTo(map_688bb2cd03ab3c2a2b9fbb17a8fac499);
#
#
#
#         function geo_json_e7f04c827736100cdf6e17b783ce5809_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e7f04c827736100cdf6e17b783ce5809 = L.geoJson(null, {
#                 onEachFeature: geo_json_e7f04c827736100cdf6e17b783ce5809_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_e7f04c827736100cdf6e17b783ce5809_add (data) {
#             geo_json_e7f04c827736100cdf6e17b783ce5809
#                 .addData(data);
#         }
#             geo_json_e7f04c827736100cdf6e17b783ce5809_add({&quot;bbox&quot;: [-122.14043432267533, 37.66752551549237, -121.25406340147727, 38.64382411165394], &quot;features&quot;: [{&quot;bbox&quot;: [-122.01354200573556, 38.07214011062084, -122.01354200573556, 38.07214011062084], &quot;geometry&quot;: {&quot;coordinates&quot;: [-122.01354200573556, 38.07214011062084], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;X&quot;: 586524.5, &quot;Y&quot;: 4214278.5, &quot;id&quot;: 329}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-121.91109039863514, 38.0792159693809, -121.91109039863514, 38.0792159693809], &quot;geometry&quot;: {&quot;coordinates&quot;: [-121.91109039863514, 38.0792159693809], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;X&quot;: 595501.8125, &quot;Y&quot;: 4215164.0, &quot;id&quot;: 328}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-121.99752602048599, 38.160812670672975, -121.99752602048599, 38.160812670672975], &quot;geometry&quot;: {&quot;coordinates&quot;: [-121.99752602048599, 38.160812670672975], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;X&quot;: 587823.0625, &quot;Y&quot;: 4224132.5, &quot;id&quot;: 327}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-121.72266810229077, 38.251577121745726, -121.72266810229077, 38.251577121745726], &quot;geometry&quot;: {&quot;coordinates&quot;: [-121.72266810229077, 38.251577121745726], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;X&quot;: 611764.3125, &quot;Y&quot;: 4234500.0, &quot;id&quot;: 326}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-121.74920312784938, 38.260505484883524, -121.74920312784938, 38.260505484883524], &quot;geometry&quot;: {&quot;coordinates&quot;: [-121.74920312784938, 38.260505484883524], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;X&quot;: 609429.0625, &quot;Y&quot;: 4235459.0, &quot;id&quot;: 325}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-121.77554171664089, 38.260927500618415, -121.77554171664089, 38.260927500618415], &quot;geometry&quot;: {&quot;coordinates&quot;: [-121.77554171664089, 38.260927500618415], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;X&quot;: 607124.0625, &quot;Y&quot;: 4235475.0, &quot;id&quot;: 324}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-121.68414693487071, 38.2381787414543, -121.68414693487071, 38.2381787414543], &quot;geometry&quot;: {&quot;coordinates&quot;: [-121.68414693487071, 38.2381787414543], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;X&quot;: 615156.125, &quot;Y&quot;: 4233060.5, &quot;id&quot;: 323}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-121.68867091600514, 38.24462337529116, -121.68867091600514, 38.24462337529116], &quot;geometry&quot;: {&quot;coordinates&quot;: [-121.68867091600514, 38.24462337529116], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {&quot;X&quot;: 614750.0625, &quot;Y&quot;: 4233770.0, &quot;id&quot;: 322}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-121.69285853592093, 38.25788613737452, -121.69285853592093, 38.25788613737452], &quot;geometry&quot;: {&quot;coordinates&quot;: [-121.69285853592093, 38.257886137374
